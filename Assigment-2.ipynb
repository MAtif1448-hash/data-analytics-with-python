# %% [markdown]
# # ASSIGNMENT - 02:-

# %% [markdown]
# # CONDITIONAL STATEMENTS:-

# %% [markdown]
# Q-1 #  A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years. Ask user for their salary and year of service and print the net bonus amount.

# %%
employee_salary = int(input('Employee Salary: '))
employee_service = int(input('Employee Service: '))
bounus_in_salary = 5
bonus_formula = employee_salary*(bounus_in_salary/100)
Total_Salary = employee_salary + bonus_formula

if employee_service >= 5:
    print('Total_Salary: ',int(Total_Salary))
else:
    print('You are not eligible for 5% bonus')
# Out:
# Employee Salary:  50000
# Employee Service:  7
# Total_Salary:  52500

# %% [markdown]
# Q-2 # Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible.

# %%
eligible_voting_age = 18

voter_age = int(input('Voter Age: '))

if voter_age >= 18:
    print('Your are eligible for voting')
else:
    print('Your are not eligible for voting')
# Out:
# Voter Age:  28
# Your are eligible for voting

# %% [markdown]
# Q-3 # Write a program to check whether a number entered by user is even or odd.

# %%
number = int(input('Enter Number: '))

if number%2 == 0:
    print('The Number is Even Number')
else:
    print('The Number is Odd Number')
# Out:
# Enter Number:  3
# The Number is Odd Number

# %% [markdown]
# Q-4 # Write a program to check whether a number is divisible by 7 or not. Show Answer.

# %%
number = int(input('Enter Number: '))

if number%7 == 0:
    print("Divisible by 7")
else:
    print("Not Divisible by 7")
# Out:
# Enter Number:  6
# Not Divisible by 7

# %% [markdown]
# Q-5 # Write a program to display "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
number = int(input('Enter Number: '))

if number % 5 == 0:
    print('Hello')
else:
    print('Bye')
# Out:
# Enter Number:  8
# Bye

# %% [markdown]
# Q-6 # Write a program to display the last digit of a number.

# %%
number = int(input('Enter Number: '))
last_digit = number % 10
print("last digit: ", last_digit)
# Out:
# Enter Number:  4569
# last digit:  9

# %% [markdown]
# Q-6 # Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = float(input('Enter Length: '))
breadth = float(input('Enter Breadth: '))

if length == breadth:
    print('It is Square')
else:
    print('It is rectangle')
# Out:
# Enter Length:  5
# Enter Breadth:  4
# It is rectangle

# %% [markdown]
# Q-7 # Take two int values from user and print greatest among them.

# %%
num1 = float(input('Enter Num1: '))
num2 = float(input('Enter Num2: '))

if num1 > num2:
    print('Num1 is greater value')
else:
    print('Num2 is greater value')
# Out:
# Enter Num1:  577
# Enter Num2:  788
# Num2 is greater value

# %% [markdown]
# Q-8 # A shop will give discount of 10% if the cost of purchased quantity is more than 1000. Ask user for quantity Suppose, one unit will cost 100. Judge and print total cost for user.

# %%
item_cost = float(input('Enter Cost : '))
discount = item_cost*10/100
final_cost = item_cost - discount

if item_cost >= 1000:
    print('final_cost: ', int(final_cost))
else:
    print('Item Cost: ', int(item_cost))
# Out:
# Enter Cost :  120
# Item Cost:  120

# %% [markdown]
# Q-9 # A school has following rules for grading system:
# a. Below 25 - F
# b. 25 to 45 - E
# c. 45 to 50 - D
# d. 50 to 60 - C
# e. 60 to 80 - B
# f. Above 80 - A

# %%
Students_Marks = float(input("Enter Students Marks: "))

if Students_Marks > 80:
    print('Grade-A')
elif Students_Marks >= 60 or Students_Marks == 80:
    print('Grade-B')
elif Students_Marks >= 50 or Students_Marks == 60:
    print('Grade-C')
elif Students_Marks >= 45 or Students_Marks == 50:
    print('Grade-D')
elif Students_Marks >= 25 or Students_Marks == 45:
    print('Grade-E')
else:
    print('Fail')
# Out:
# Enter Students Marks:  25
# Grade-E

# %% [markdown]
# Q-10 # A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# Number of classes held
#
# Number of classes attended.
#
# And print
#
# percentage of class attended
#
# Is student is allowed to sit in exam or not.

# %%
total_classes = int(input("Total Classes held: "))
total_classes_attended = int(input("Total Classes Attended: "))
attendence_percentage = total_classes_attended/total_classes*(100)

if attendence_percentage >= 75:
    print("Attendence Percentage: ",attendence_percentage,'%')
    print('Remarks: You are allowed to sit in the exam.')
else:
    print("Attendence Percentage: ",int(attendence_percentage),'%')
    print('Remarks: You are not allowed to sit in the exam.')
# Out:
# Total Classes held:  45
# Total Classes Attended:  16
# Attendence Percentage:  35 %
# Remarks: You are not allowed to sit in the exam.

# %% [markdown]
# Q-11 # Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
total_classes = int(input("Total Classes held: "))
total_classes_attended = int(input("Total Classes Attended: "))
attendence_percentage = total_classes_attended/total_classes*(100)
medical_cause = str(input("Enter Medical Cause: "))

if attendence_percentage >= 75 and medical_cause == "No":
    print("Attendence Percentage: ",int(attendence_percentage),'%')
    print('Remarks: You are allowed to sit in the exam.')
else:
    print("Attendence Percentage: ",int(attendence_percentage),'%')
    print('Remarks: You are not allowed to sit in the exam.')
# Out:
# Total Classes held:  45
# Total Classes Attended:  41
# Enter Medical Cause:  No
# Attendence Percentage:  91 %
# Remarks: You are allowed to sit in the exam.

# %% [markdown]
# Q-12 # Write a program to check if a year is leap year or not. If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input('Enten Year: '))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print('Leap Year')
        else: 
            print('Not a Leap Year')
    else:
        print('Leap Year')
else:
    print("Not a Leap Year")
# Out:
# Enten Year:  2028
# Leap Year

# %% [markdown]
# Q-12 # Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input('Enter Age: '))
gender = str(input('Enter Gender: '))
martial_status = str(input('Enter Martial Status: '))

if gender == "female" and (martial_status == "married" or martial_status == "single") and (age > 20):
    print('Remarks: Female employees will only be work at urban areas whether they have any age range and martial status.')

elif gender == "male" and (martial_status == "married" or martial_status == "single") and (age > 40 and age <= 60):
    print('Aged male employees will als obe work at urban areas whether they have any age range and martial status.')

elif gender == "male" and (martial_status == "married" or martial_status == "single") and (age > 20 or age <= 40):
    print('young and Mid aged employees can be work any where whether they have any age range and martial status.')

else:
    print('Error')
# Out:
# Enter Age:  21
# Enter Gender:  male
# Enter Martial Status:  married
# young and Mid aged employees can be work any where whether they have any age range and martial status.

# %% [markdown]
# Q-13 # Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria : Unit Price upto 100 units no charge Next 200 units Rs 5 per unit After 200 units Rs 10 per unit (For example if input unit is 350 than total bill amount is Rs.3500 (For example if input unit is 97 than total bill amount is Rs.0 (For example if input unit is 150 than total bill amount is Rs.750.

# %%
# Electric City Bill Calculation:-
electric_units = int(input("Enter Units: "))
unit_price_1 = 0 #for upto 100 unit usage
unit_price_2 = 20 #for upto 200 unit usage
unit_price_3 = 35 #for more then 200 unit usage

if electric_units <= 100:
    print("Total Electric Bill: ","Rs.",electric_units*unit_price_1,"/-")

elif electric_units <= 200:
    print("Total Electric Bill: ","Rs.",electric_units*unit_price_2,"/-")
    
else:
     print("Total Electric Bill: ","Rs.",electric_units*unit_price_3,"/-")
# Out:
# Enter Units:  201
# Total Electric Bill:  Rs. 7035 /-

# %% [markdown]
# Q-14 # Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input('Enter Age of Person 1: '))
age2 = int(input('Enter Age of Person 2: '))
age3 = int(input('Enter Age of Person 3: '))

if age1 >= age2 and age1 >= age3:
    oldest = age1
elif age2 >= age1 and age2 >= age3:
    oldest = age2
else:
    oldest = age3

if age1 <= age2 and age1 <= age3:
    youngest = age1
elif age2 <= age1 and age2 <= age3:
    youngest = age2
else:
    youngest = age3

print('Oldest Age: ', oldest)
print('Youngest Age: ', youngest)
# Out:
# Enter Age of Person 1:  35
# Enter Age of Person 2:  25
# Enter Age of Person 3:  19
# Oldest Age:  35
# Youngest Age:  19
