# %% [markdown]
# # Assignment-4:-

# %% [raw]
# Q-1 # Create a dictionary called student with keys: name, age, course, city. Print each value.

# %%
student = {
    "name": "Atif",
    "age": 20,
    "course": "Data Analytics",
    "city": "Karachi"
}

print(student["name"])
print(student["age"])
print(student["course"])
print(student["city"])
# Out:
# Atif
# 20
# Data Analytics
# Karachi

# %% [raw]
# Q-2 # Adding and updating values.

# %%
car = {
    "brand": "Toyota",
    "model": "Corolla",
    "year": 2018
}

car["color"] = "White"   
car["year"] = 2022       

print(car)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2022, 'color': 'White'}

# %% [raw]
# Q-3 # Loop through dictionary.

# %%
person = {
    "name": "Faraz",
    "age": 28,
    "city": "Karachi"
}

for key, value in person.items():
    print(key, ":", value)
# Out:
# name : Faraz
# age : 28
# city : Karachi

# %% [raw]
# Q-4 # Count Frequency of Numbers.

# %%
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

freq = {}
for n in numbers:
    freq[n] = freq.get(n, 0) + 1

print(freq)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [raw]
# Q-5 # Word counter.

# %%
sentence = input("Enter a sentence: ")

freq = {}
for word in sentence.lower().split():
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# Enter a sentence:  the cat and the dog and the bird
# {'the': 3, 'cat': 1, 'and': 2, 'dog': 1, 'bird': 1}

# %% [raw]
# Q-6 # Marks total and average.

# %%
marks = {"Math": 80, "English": 70, "Physics": 90}

total = sum(marks.values())
average = total / len(marks)

print("Total:", total)
print("Average:", average)
# Out:
# Total: 240
# Average: 80.0

# %% [raw]
# Q-7 # Highest scoring student.

# %%
students = {
    "Ali": 85,
    "Sara": 92,
    "Ahmed": 78,
    "Zara": 95
}

top = max(students, key=students.get)
print("Highest scoring student:", top, "with", students[top])
# Out:
# Highest scoring student: Zara with 95

# %% [raw]
# Q-8 # Merge Dictionaries.

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged = {**dict1, **dict2}
print(merged)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [raw]
# Q-9 # Mini Project: Contact Book.

# %%
contacts = {}

for i in range(3):
    name = input(f"Contact {i + 1} name: ")
    phone = input(f"Contact {i + 1} phone: ")
    contacts[name] = phone

search = input("Search name: ")

if search in contacts:
    print("Phone:", contacts[search])
else:
    print("Contact not found")
# Out:
# Contact 1 name:  Muhammad
# Contact 1 phone:  03325691369
# Contact 2 name:  Hamza
# Contact 2 phone:  03116985159
# Contact 3 name:  Junaid
# Contact 3 phone:  03332514789
# Search name:  Ubaid
# Contact not found
